# %% [markdown]
# # a_import
#
# Run all cells. Outputs are written to this task's `output/` folder.

# %%
# %run ~/Desktop/SHL_dblp_comparable/common/core.ipynb
# Out:
# /Users/slmagid/miniforge3/envs/research313/lib/python3.13/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %%
from pathlib import Path
import shutil
import pandas as pd
ROOT = Path.home() / 'Desktop' / 'SHL_dblp_comparable'
SOURCE = Path.home() / 'Desktop' / 'SHL_SPAARW2' / 'prepare' / 'output' / 'df_traj_all.csv'
OUTPUT = ROOT / 'a_import' / 'output'
if OUTPUT.exists():
    shutil.rmtree(OUTPUT)
OUTPUT.mkdir(parents=True, exist_ok=True)
destination = OUTPUT / 'df_traj_all.csv'
shutil.copyfile(SOURCE, destination)
pd.DataFrame([{'source': str(SOURCE), 'file': destination.name, 'bytes': destination.stat().st_size, 'sha256': sha256(destination)}]).to_csv(OUTPUT / 'manifest.csv', index=False)
write_json(OUTPUT / 'quality_report.json', {'status': 'passed', 'source': str(SOURCE), 'destination': destination.name, 'policy': 'byte-for-byte import; wrangling occurs downstream'})
print(destination)
# Out:
# /Users/slmagid/Desktop/SHL_dblp_comparable/a_import/output/df_traj_all.csv
